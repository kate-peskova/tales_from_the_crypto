# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
pip install newsapi-python==0.2.5
# Out:
# Collecting newsapi-python==0.2.5
#   Using cached newsapi_python-0.2.5-py2.py3-none-any.whl
# Collecting requests==2.21.0
#   Using cached requests-2.21.0-py2.py3-none-any.whl (57 kB)
# Collecting urllib3<1.25,>=1.21.1
#   Using cached urllib3-1.24.3-py2.py3-none-any.whl (118 kB)
# Collecting idna<2.9,>=2.5
#   Using cached idna-2.8-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from requests==2.21.0->newsapi-python==0.2.5) (2021.5.30)
# Collecting chardet<3.1.0,>=3.0.2
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Installing collected packages: urllib3, idna, chardet, requests, newsapi-python
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.6
#     Uninstalling urllib3-1.26.6:
#       Successfully uninstalled urllib3-1.26.6
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 4.1.5 requires pyqt5<5.13; python_version >= "3", which is not installed.
# spyder 4.1.5 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
# Successfully installed chardet-3.0.4 idna-2.8 newsapi-python-0.2.5 requests-2.21.0 urllib3-1.24.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# Initializing imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/kate/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Reading api key environment variable
load_dotenv()
# Out:
# True

# %%
# Creating a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=os.getenv("NEWS_API_KEY"))

# %%
# Fetching the Bitcoin news articles
bitcoin_articles = newsapi.get_everything(q="bitcoin", language="en")

# %%
# Fetching the Ethereum news articles
ethereum_articles = newsapi.get_everything(q="ethereum", language="en")

# %%
# Creating the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "date": date,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu})
        
    except AttributeError:
        pass
    
# Creating a DataFrame
bitcoin_df = pd.DataFrame(bitcoin_sentiments)

# Reordering DataFrame columns
cols = ["date", "text", "Compound", "Negative", "Neutral", "Positive"]
bitcoin_df = bitcoin_df[cols]
bitcoin_df.head()
# Out:
#          date                                               text  Compound  \
# 0  2021-10-06  <ul><li>Bitcoin, in terms of market value, ros...    0.3400
# 1  2021-10-04  JPMorgan CEO Jamie Dimon is still not a Bitcoi...   -0.2411
# 2  2021-10-06  How high are the chances of Bitcoin sustaining...    0.4939
# 3  2021-10-10  Specifically, why did someone make a massive p...    0.5461
# 4  2021-10-28  Theres a big new presence slurping up power fr...    0.3612
#
#    Negative  Neutral  Positive
# 0     0.000    0.924     0.076
# 1     0.116    0.884     0.000
# 2     0.000    0.781     0.219
# 3     0.000    0.879     0.121
# 4     0.000    0.904     0.096

# %%
# Creating the Ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_articles["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "date": date,
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu})
        
    except AttributeError:
        pass
    
# Creating a DataFrame
ethereum_df = pd.DataFrame(ethereum_sentiments)
# Reordering DataFrame columns
cols = ["date", "text", "Compound", "Negative", "Neutral", "Positive"]
ethereum_df = ethereum_df[cols]
ethereum_df.head()
# Out:
#          date                                               text  Compound  \
# 0  2021-10-16  A new cross-chain bridge is currently connecte...    0.0000
# 1  2021-10-14  Mark Cuban has some advice for people who are ...    0.0000
# 2  2021-10-11  An immersive art installation, which will be c...    0.0000
# 3  2021-10-12  Coinbase NFT\r\nRobert Nickelsberg/Getty Image...    0.0000
# 4  2021-10-22  Bitcoin and Ethereum.\r\nNurPhoto / Getty Imag...    0.8225
#
#    Negative  Neutral  Positive
# 0       0.0    1.000     0.000
# 1       0.0    1.000     0.000
# 2       0.0    1.000     0.000
# 3       0.0    1.000     0.000
# 4       0.0    0.792     0.208

# %%
# Describing the Bitcoin Sentiment
bitcoin_df.describe()
# Out:
#         Compound   Negative   Neutral   Positive
# count  20.000000  20.000000  20.00000  20.000000
# mean    0.210935   0.008850   0.92435   0.066850
# std     0.296789   0.028664   0.07608   0.076818
# min    -0.241100   0.000000   0.78100   0.000000
# 25%     0.000000   0.000000   0.88275   0.000000
# 50%     0.012900   0.000000   0.91400   0.041000
# 75%     0.467575   0.000000   1.00000   0.107500
# max     0.755800   0.116000   1.00000   0.219000

# %%
# Describing the Ethereum Sentiment
ethereum_df.describe()
# Out:
#         Compound   Negative    Neutral   Positive
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.143395   0.007100   0.956700   0.036200
# std     0.293811   0.023092   0.074001   0.063669
# min    -0.226300   0.000000   0.792000   0.000000
# 25%     0.000000   0.000000   0.925000   0.000000
# 50%     0.000000   0.000000   1.000000   0.000000
# 75%     0.119175   0.000000   1.000000   0.071250
# max     0.822500   0.094000   1.000000   0.208000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin
#
# Q: Which coin had the highest compound score?
#
# A: Etherium
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiating the lemmatizer
lemmatizer = WordNetLemmatizer()

# Creating a list of stopwords
sw = stopwords.words('english')

# Expanding the default stopwords list if necessary
other_sw = []

# %%
# Completing the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Removing the punctuation from text
    regex = re.compile("[^a-zA-Z0-9 ]")
    re_clean = regex.sub('', text)
   
    # Creating a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatizing words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Converting the words to lowercase
    tokens = [word.lower() for word in lem if word.lower() not in sw]
    
    # Removing the stop words
    remove_sw = set(stopwords.words('english'))    
    
    return tokens

# %%
# Creating a new tokens column for Bitcoin
bitcoin_df["tokens"] = bitcoin_df.text.apply(tokenizer)
bitcoin_df.head()
# Out:
#          date                                               text  Compound  \
# 0  2021-10-06  <ul><li>Bitcoin, in terms of market value, ros...    0.3400
# 1  2021-10-04  JPMorgan CEO Jamie Dimon is still not a Bitcoi...   -0.2411
# 2  2021-10-06  How high are the chances of Bitcoin sustaining...    0.4939
# 3  2021-10-10  Specifically, why did someone make a massive p...    0.5461
# 4  2021-10-28  Theres a big new presence slurping up power fr...    0.3612
#
#    Negative  Neutral  Positive  \
# 0     0.000    0.924     0.076
# 1     0.116    0.884     0.000
# 2     0.000    0.781     0.219
# 3     0.000    0.879     0.121
# 4     0.000    0.904     0.096
#
#                                               tokens
# 0  [ullibitcoin, term, market, value, rose, 46, 5...
# 1  [jpmorgan, ceo, jamie, dimon, still, bitcoin, ...
# 2  [high, chance, bitcoin, sustaining, gain, push...
# 3  [specifically, someone, make, massive, purchas...
# 4  [theres, big, new, presence, slurping, power, ...

# %%
# Creating a new tokens column for Ethereum
ethereum_df["tokens"] = ethereum_df.text.apply(tokenizer)
ethereum_df.head()
# Out:
#          date                                               text  Compound  \
# 0  2021-10-16  A new cross-chain bridge is currently connecte...    0.0000
# 1  2021-10-14  Mark Cuban has some advice for people who are ...    0.0000
# 2  2021-10-11  An immersive art installation, which will be c...    0.0000
# 3  2021-10-12  Coinbase NFT\r\nRobert Nickelsberg/Getty Image...    0.0000
# 4  2021-10-22  Bitcoin and Ethereum.\r\nNurPhoto / Getty Imag...    0.8225
#
#    Negative  Neutral  Positive  \
# 0       0.0    1.000     0.000
# 1       0.0    1.000     0.000
# 2       0.0    1.000     0.000
# 3       0.0    1.000     0.000
# 4       0.0    0.792     0.208
#
#                                               tokens
# 0  [new, crosschain, bridge, currently, connected...
# 1  [mark, cuban, ha, advice, people, new, investi...
# 2  [immersive, art, installation, converted, nfts...
# 3  [coinbase, nftrobert, nickelsberggetty, images...
# 4  [bitcoin, ethereumnurphoto, getty, imagesif, b...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generating the Bitcoin N-grams where N=2
btc_string = bitcoin_df["text"].str.cat()
btc_tokens =  tokenizer(btc_string)
btc_bigrams = Counter(ngrams(btc_tokens, n=2))
btc_bigrams.most_common(5)
# Out:
# [(('reuters', 'bitcoin'), 5),
#  (('cryptocurrency', 'bitcoin'), 4),
#  (('illustration', 'taken'), 4),
#  (('charsa', 'representation'), 3),
#  (('representation', 'virtual'), 3)]

# %%
# Generating the Ethereum N-grams where N=2
eth_string = ethereum_df["text"].str.cat()
eth_tokens =  tokenizer(eth_string)
eth_bigrams = Counter(ngrams(eth_tokens, n=2))
eth_bigrams.most_common(5)
# Out:
# [(('illustration', 'taken'), 6),
#  (('taken', 'june'), 4),
#  (('reuters', 'bitcoin'), 4),
#  (('charsa', 'representation'), 4),
#  (('2021', 'reutersdado'), 3)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
token_count(btc_tokens, N=10)
# Out:
# [('bitcoin', 20),
#  ('us', 6),
#  ('reuters', 6),
#  ('high', 4),
#  ('charsa', 4),
#  ('cryptocurrency', 4),
#  ('illustration', 4),
#  ('taken', 4),
#  ('2021', 4),
#  ('oct', 4)]

# %%
# Use token_count to get the top 10 words for Ethereum
token_count(eth_tokens, N=10)
# Out:
# [('bitcoin', 10),
#  ('cryptocurrency', 9),
#  ('ethereum', 8),
#  ('nfts', 6),
#  ('illustration', 6),
#  ('taken', 6),
#  ('ha', 5),
#  ('2021', 5),
#  ('reuters', 5),
#  ('representation', 5)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
conda install -c conda-forge wordcloud
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::_anaconda_depends==2020.07=py38_0
#   - defaults/osx-64::anaconda==custom=py38_1
# done
#
# ## Package Plan ##
#
#   environment location: /Users/kate/opt/anaconda3
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bitarray-2.3.4             |   py38h96a0964_1         134 KB  conda-forge
#     ca-certificates-2021.10.8  |       h033912b_0         139 KB  conda-forge
#     certifi-2021.10.8          |   py38h50d1736_0         145 KB  conda-forge
#     conda-4.10.3               |   py38h50d1736_2         3.1 MB  conda-forge
#     openssl-1.1.1l             |       h0d85af4_0         1.9 MB  conda-forge
#     wordcloud-1.8.1            |   py38h96a0964_1         170 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   bitarray           conda-forge/osx-64::bitarray-2.3.4-py38h96a0964_1
#   python_abi         conda-forge/osx-64::python_abi-3.8-2_cp38
#   wordcloud          conda-forge/osx-64::wordcloud-1.8.1-py38h96a0964_1
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2021.7.5-h~ --> conda-forge::ca-certificates-2021.10.8-h033912b_0
#   certifi            pkgs/main::certifi-2021.5.30-py38hecd~ --> conda-forge::certifi-2021.10.8-py38h50d1736_0
#   conda              pkgs/main::conda-4.10.3-py38hecd8cb5_0 --> conda-forge::conda-4.10.3-py38h50d1736_2
#   openssl              pkgs/main::openssl-1.1.1k-h9ed2024_0 --> conda-forge::openssl-1.1.1l-h0d85af4_0
#
#
#
# Downloading and Extracting Packages
# conda-4.10.3         | 3.1 MB    | ##################################### | 100%
# openssl-1.1.1l       | 1.9 MB    | ##################################### | 100%
# ca-certificates-2021 | 139 KB    | ##################################### | 100%
# bitarray-2.3.4       | 134 KB    | ##################################### | 100%
# wordcloud-1.8.1      | 170 KB    | ##################################### | 100%
# certifi-2021.10.8    | 145 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generating the Bitcoin word cloud
cloud_string = ' '.join(btc_tokens)
wc = WordCloud().generate(cloud_string)
plt.imshow(wc)

# %%
# Generating the Ethereum word cloud
eth_cloud_string = ' '.join(eth_tokens)
wc = WordCloud().generate(eth_cloud_string)
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
conda install -c conda-forge spacy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/kate/opt/anaconda3
#
#   added / updated specs:
#     - spacy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     catalogue-2.0.6            |   py38h50d1736_0          31 KB  conda-forge
#     cymem-2.0.6                |   py38ha048514_0          33 KB  conda-forge
#     cython-blis-0.7.4          |   py38ha1b04c9_0         5.1 MB  conda-forge
#     murmurhash-1.0.6           |   py38ha048514_0          22 KB  conda-forge
#     pathy-0.6.1                |     pyhd8ed1ab_0          37 KB  conda-forge
#     preshed-3.0.6              |   py38ha048514_0          87 KB  conda-forge
#     pydantic-1.8.2             |   py38h96a0964_0         2.1 MB  conda-forge
#     smart_open-5.2.1           |     pyhd8ed1ab_0          43 KB  conda-forge
#     spacy-3.1.3                |   py38hb0f0857_0         5.3 MB  conda-forge
#     srsly-2.4.2                |   py38ha048514_0         506 KB  conda-forge
#     thinc-8.0.12               |   py38hb0f0857_0         649 KB  conda-forge
#     typer-0.4.0                |     pyhd8ed1ab_0          26 KB  conda-forge
#     typing-extensions-3.10.0.2 |       hd8ed1ab_0           8 KB  conda-forge
#     typing_extensions-3.10.0.2 |     pyha770c72_0          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   catalogue          conda-forge/osx-64::catalogue-2.0.6-py38h50d1736_0
#   cymem              conda-forge/osx-64::cymem-2.0.6-py38ha048514_0
#   cython-blis        conda-forge/osx-64::cython-blis-0.7.4-py38ha1b04c9_0
#   dataclasses        conda-forge/noarch::dataclasses-0.8-pyhc8e2a94_3
#   murmurhash         conda-forge/osx-64::murmurhash-1.0.6-py38ha048514_0
#   pathy              conda-forge/noarch::pathy-0.6.1-pyhd8ed1ab_0
#   preshed            conda-forge/osx-64::preshed-3.0.6-py38ha048514_0
#   pydantic           conda-forge/osx-64::pydantic-1.8.2-py38h96a0964_0
#   shellingham        conda-forge/noarch::shellingham-1.4.0-pyh44b312d_0
#   smart_open         conda-forge/noarch::smart_open-5.2.1-pyhd8ed1ab_0
#   spacy              conda-forge/osx-64::spacy-3.1.3-py38hb0f0857_0
#   spacy-legacy       conda-forge/noarch::spacy-legacy-3.0.8-pyhd8ed1ab_0
#   srsly              conda-forge/osx-64::srsly-2.4.2-py38ha048514_0
#   thinc              conda-forge/osx-64::thinc-8.0.12-py38hb0f0857_0
#   typer              conda-forge/noarch::typer-0.4.0-pyhd8ed1ab_0
#   typing-extensions  conda-forge/noarch::typing-extensions-3.10.0.2-hd8ed1ab_0
#   wasabi             conda-forge/noarch::wasabi-0.8.2-pyh44b312d_0
#
# The following packages will be UPDATED:
#
#   libcxx                         pkgs/main::libcxx-10.0.0-1 --> conda-forge::libcxx-12.0.1-habf9029_0
#   typing_extensions  pkgs/main::typing_extensions-3.10.0.0~ --> conda-forge::typing_extensions-3.10.0.2-pyha770c72_0
#
#
#
# Downloading and Extracting Packages
# cython-blis-0.7.4    | 5.1 MB    | ##################################### | 100%
# spacy-3.1.3          | 5.3 MB    | ##################################### | 100%
# typing-extensions-3. | 8 KB      | ##################################### | 100%
# pydantic-1.8.2       | 2.1 MB    | ##################################### | 100%
# smart_open-5.2.1     | 43 KB     | ##################################### | 100%
# srsly-2.4.2          | 506 KB    | ##################################### | 100%
# pathy-0.6.1          | 37 KB     | ##################################### | 100%
# murmurhash-1.0.6     | 22 KB     | ##################################### | 100%
# cymem-2.0.6          | 33 KB     | ##################################### | 100%
# preshed-3.0.6        | 87 KB     | ##################################### | 100%
# thinc-8.0.12         | 649 KB    | ##################################### | 100%
# catalogue-2.0.6      | 31 KB     | ##################################### | 100%
# typer-0.4.0          | 26 KB     | ##################################### | 100%
# typing_extensions-3. | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
#      |████████████████████████████████| 13.6 MB 405 kB/s eta 0:00:01
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from en-core-web-sm==3.1.0) (3.1.3)
# Requirement already satisfied: numpy>=1.15.0 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.20.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.9 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.12)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.62.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.21.0)
# Requirement already satisfied: setuptools in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (52.0.0.post20210125)
# Requirement already satisfied: packaging>=20.0 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (21.0)
# Requirement already satisfied: jinja2 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.10.0.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2021.10.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/kate/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.1.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenating all of the Bitcoin text together
btc_text = ' '.join(bitcoin_df['text'].values)

# %%
# Running the NER processor on all of the text
btc_doc = nlp(btc_text)

# Adding a title to the document
btc_doc.user_data['title'] = 'Bitcoin Named Entity Recognition'

# %%
# Rendering the visualization
displacy.render(btc_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin Named Entity Recognition</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">&lt;ul&gt;&lt;li&gt;Bitcoin, in terms of market value, rose
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4.6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  to $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     53,859.6.&lt;/li&gt;&lt;li
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# &gt;It passed $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  mark for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . &lt;/li&gt;&lt;li&gt;Bitcoin fell below $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     50,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in early September.&lt;/li&gt;… [+821 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JPMorgan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  CEO
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jamie Dimon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is still not a Bitcoin fan despite rapid price appreciationfrom U.Today https://ift.tt/3iyi5nR https://ift.tt/eA8V8J How high are the chances of Bitcoin sustaining its gains and pushing altcoins higher?from U.Today https://ift.tt/3BkD5px https://ift.tt/eA8V8J Specifically, why did someone make a massive purchase of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1.6 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of bitcoin on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a couple of minutes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# </br>While many see this huge buy as a signal of bullishness, there may be more… [+8443 chars] Theres a big new presence slurping up power from the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  grid, and its growing: bitcoin miners. New research shows that the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has overtaken
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  as the top global destination for bitcoin mining … [+3088 chars]
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Wall Street Journal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ran a piece on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  recent nuclear-bitcoin deals that may signal a growing trend in the industry. The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Journal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  piece reflects a small but growing sense of excitemen… [+9512 chars] For all the talk of democratizing finance, the vast majority of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>As flagged by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , newly released data by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the National Bureau
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  … [+4274 chars] Th

# %%
# Listing all Entities
[ent for ent in btc_doc.ents]
# Out:
# [4.6%,
#  53,859.6.</li><li,
#  50,000,
#  first,
#  four weeks,
#  Tuesday,
#  50,000,
#  JPMorgan,
#  Jamie Dimon,
#  $1.6 billion,
#  Wednesday,
#  a couple of minutes,
#  U.S.,
#  U.S.,
#  China,
#  Last week,
#  the Wall Street Journal,
#  three,
#  Journal,
#  Bitcoin,
#  Bloomberg,
#  the National Bureau,
#  SEC,
#  two,
#  Digital,
#  IMF,
#  Kristalina Georgieva,
#  Elon Musk,
#  Tuesday,
#  U.S.,
#  Canada,
#  Bitcoin,
#  Alberta,
#  Link Global,
#  June 29, 2021,
#  REUTERS,
#  Dado Ruvic/IllustrationHONG KONG,
#  Oct 21,
#  Reuters,
#  October 19, 2021,
#  REUTERS,
#  Edgar SuLONDON,
#  Oct 20,
#  Reuters,
#  Securities and Exchange Commission,
#  Andrew Kelly,
#  The US Securities and Exchange Commission,
#  as many as four,
#  October,
#  October 18, 2021,
#  REUTERS,
#  Edgar SuSINGAPORE,
#  Oct 19,
#  Reuters,
#  six-month,
#  October 19, 2021,
#  REUTERS,
#  Edgar SuHONG KONG,
#  Oct 20,
#  Reuters,
#  Wednesday,
#  first,
#  U.S.,
#  Conway G. Gittens,
#  Reuters,
#  Reuters,
#  six-month,
#  Tuesday,
#  U.S.,
#  NurPhoto,
#  Getty Images,
#  first,
#  Tuesday,
#  ProShares,
#  ETF]

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenating all of the Ethereum text together
eth_text = ' '.join(ethereum_df['text'].values)

# %%
# Running the NER processor on all of the text
eth_doc = nlp(eth_text)

# Adding a title to the document
eth_doc.user_data['title'] = 'Ethereum Named Entity Recognition'

# %%
# Rendering the visualization
displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum Named Entity Recognition</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">A new cross-chain bridge is currently connected to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  through a cross-chain bridge, with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cardano
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nervos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  announced that
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Force Bridge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  is … [+3114 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark Cuban
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>As an investment, I think ethereum has the most upside, he told
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CNBC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Make It
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Bitcoin, he added, is better… [+1139 chars] An immersive art installation, which will be converted into NFTs in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     September 30, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>FTX.US, an affiliate of cryptocurrency exchange
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FTX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , is launching an… [+2138 chars] Coinbase
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Robert Nickelsberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# /
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coinbase Global
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is joining the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  bandwagon by launching its own marketplace by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the end of the year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>The largest cryptocurrency exchange in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NurPhoto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>If the blockbuster success of the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# -ever bitcoin-futures exchange-traded fund is any indication, the debut of an ethereum-based one may just be as … [+3057 chars] Representations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, Litecoin are placed on PC motherboard in this illustration taken,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 29, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     REUTERS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dado Ruvic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span

# %%
# Listing all Entities
[ent for ent in eth_doc.ents]
# Out:
# [Ethereum,
#  Cardano,
#  Nervos ,
#  today,
#  the Force Bridge,
#  Mark Cuban,
#  CNBC,
#  Wednesday,
#  Hong Kong,
#  September 30, 2021,
#  FTX,
#  NFT,
#  Robert Nickelsberg,
#  Getty Images,
#  Coinbase Global,
#  NFT,
#  the end of the year,
#  US,
#  NurPhoto,
#  first,
#  June 29, 2021,
#  REUTERS,
#  Dado Ruvic,
#  Oct,
#  second,
#  4,400,
#  Friday,
#  Ethereum,
#  Bitcoin’s,
#  second,
#  Reuters,
#  1,
#  Reuters,
#  9.46%,
#  47,980.97,
#  20:12 GMT,
#  Friday,
#  4,146.54,
#  June 14, 2021,
#  REUTERS,
#  Edgar Su/IllustrationOct,
#  Reuters,
#  7.11%,
#  55,162.92,
#  20,
#  November 19, 2020,
#  REUTERS,
#  Dado Ruvic/Illustration/File PhotoOct,
#  Reuters,
#  5,
#  August 6, 2021,
#  REUTERS,
#  Dado Ruvic/Illustration/File,
#  30,
#  Reuters,
#  5.23%,
#  43,716.97,
#  22,
#  NFT,
#  Getty Images,
#  the minute,
#  Vitalik Buterin,
#  One year from now,
#  Ethereum,
#  NFT,
#  Getty Images,
#  the minute,
#  June 29, 2021,
#  REUTERS,
#  Dado Ruvic/Illustration/File Photo,
#  Ethereum,
#  June 14, 2021,
#  REUTERS,
#  Edgar Su/IllustrationNEW,
#  NFT,
#  Sashkin
#  Ripple,
#  $250 million,
#  Wednesday,
#  The Creator Fund]

# %% [markdown]
# ---
